# %%
import h5py

path = '/home/dani/PFM/data/wide_deep_mnist.h5'

col = 7

with h5py.File(path, 'r') as f:
    print(f['feature_bins'])
    print(f['training']['features'])
    data = f['training']['features']
    num = len(data)
    a = [[n, 0] for n in range(num)]
    b = [d[col] for d in data]
    c = [num, 1]
    print(b)
# Out:
# [u'feature_bins', u'testing', u'training', u'validation']
# <HDF5 dataset "features": shape (2637, 8), type "|O">
# ...

# %%
import widedeep.mnist_prepare as mnist

# %%
voc = mnist.read_vocabulary(mnist.VOC_PATH)

# %%
voc.shape
# Out:
# (350, 128)
